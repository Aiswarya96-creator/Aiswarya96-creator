# %% [markdown]
# <a href="https://colab.research.google.com/github/Aiswarya96-creator/Aiswarya96-creator/blob/main/assignment_visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
carcrashes=sns.load_dataset('car_crashes')
carcrashes
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
carcrashes['alcohol'].value_counts()
# Out:
# alcohol
# 5.208     2
# 5.640     1
# 4.525     1
# 5.824     1
# 3.360     1
# 3.808     1
# 3.888     1
# 4.860     1
# 1.593     1
# 5.191     1
# 3.900     1
# 7.175     1
# 4.437     1
# 4.352     1
# 4.205     1
# 3.925     1
# 4.272     1
# 4.922     1
# 6.765     1
# 4.530     1
# 4.000     1
# 2.870     1
# 3.948     1
# 2.784     1
# 5.456     1
# 5.474     1
# 9.416     1
# 5.215     1
# 4.704     1
# 3.480     1
# 3.136     1
# 4.968     1
# 3.567     1
# 10.038    1
# 4.794     1
# 5.771     1
# 3.328     1
# 5.642     1
# 4.218     1
# 9.799     1
# 6.402     1
# 5.655     1
# 7.372     1
# 1.808     1
# 4.080     1
# 3.429     1
# 3.498     1
# 6.664     1
# 4.554     1
# 5.568     1
# Name: count, dtype: int64

# %%
carcrashes.nunique()
# Out:
# total             45
# speeding          50
# alcohol           50
# not_distracted    50
# no_previous       50
# ins_premium       51
# ins_losses        51
# abbrev            51
# dtype: int64

# %%
carcrashes['speeding'].unique()
# Out:
# array([7.332, 7.421, 6.51 , 4.032, 4.2  , 5.032, 4.968, 6.156, 2.006,
#        3.759, 2.964, 9.45 , 5.508, 4.608, 3.625, 2.669, 4.806, 4.066,
#        7.175, 5.738, 4.25 , 1.886, 3.384, 2.208, 2.64 , 6.923, 8.346,
#        1.937, 5.439, 4.06 , 1.792, 3.496, 3.936, 6.552, 5.497, 3.948,
#        6.368, 4.224, 9.1  , 3.774, 9.082, 6.014, 4.095, 7.76 , 4.859,
#        4.08 , 2.413, 4.452, 8.092, 7.308])

# %%
carcrashes.drop_duplicates()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
sns.scatterplot(data=carcrashes,x='alcohol',y='speeding',hue='abbrev')
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %%
sns.pairplot(data=carcrashes,hue='abbrev')

# %%
corr=carcrashes.corr(numeric_only=True)
corr
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >
